# %% [markdown]
# # ETL Pipeline
#
# This notebook follows an ELT (Extract, Load, Transform) approach:
# 1. Extract: Download historical NDBC buoy data from NOAA.
# 2. Transform: Initial pass at cleaned and parsed data into an analytics-ready format.
# 3. Load: Store the curated data in a data lake (S3) with minimal processing.
#
# **Outcome:** An Athena table that provides SQL access to the cleaned dataset for analysis and downstream machine learning workflows.
#
# ## Notebook Setup

# %%
# !pip install ndbc-api
# Out:
# Requirement already satisfied: ndbc-api in /opt/conda/lib/python3.12/site-packages (0.25.10.28.1)
# Requirement already satisfied: beautifulsoup4<5,>=4 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (4.14.3)
# Requirement already satisfied: h5netcdf<2.0.0,>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (1.8.1)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (1.1)
# Requirement already satisfied: numpy>=1.26.3 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (2.3.3)
# Requirement already satisfied: requests>=2.10.0 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (2.32.5)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (1.16.3)
# Requirement already satisfied: xarray>=2022.6.0 in /opt/conda/lib/python3.12/site-packages (from ndbc-api) (2026.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4->ndbc-api) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4->ndbc-api) (4.15.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from h5netcdf<2.0.0,>=1.6.1->ndbc-api) (24.2)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.12/site-packages (from html5lib<2.0,>=1.1->ndbc-api) (1.17.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.12/site-packages (from html5lib<2.0,>=1.1->ndbc-api) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->ndbc-api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->ndbc-api) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->ndbc-api) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.10.0->ndbc-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.10.0->ndbc-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.10.0->ndbc-api) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.10.0->ndbc-api) (2025.11.12)

# %%
import sys
from pathlib import Path

# Add the src folder (relative to the notebook) to sys.path
src_path = Path("../src").resolve()  # notebooks/etl_pipeline.ipynb
sys.path.append(str(src_path))

from s3_utils import get_s3_client, get_sagemaker_bucket, verify_bucket, upload_df_to_s3
from data_utils import fetch_ndbc_data, clean_ndbc_data
from plot_utils import plot_ndbc_histograms
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Create S3 Bucket
#
# Only need to run this once.

# %%
# Setup S3 and bucket
s3_client = get_s3_client()
bucket = get_sagemaker_bucket()

# %%
verify_bucket(bucket)
# Out:
# [INFO] Bucket 'sagemaker-us-east-1-318401170150' exists.
# True

# %% [markdown]
# ## Extract
#
# Pull NDBC buoy data using ndbc-api.

# %%
BUOY_ID = "46086"
START_DATE = "2023-01-01"
END_DATE = "2026-02-01"

raw_data = fetch_ndbc_data(BUOY_ID, START_DATE, END_DATE)

# %%
raw_data.head()
# Out:
#                                  WDIR  WSPD  GST  WVHT    DPD   APD    MWD  \
# timestamp           station_id
# 2023-01-01 00:00:00 46086       171.0   4.5  5.6   NaN    NaN   NaN    NaN
# 2023-01-01 00:10:00 46086       172.0   4.7  5.9  1.63  11.43  9.33  283.0
# 2023-01-01 00:20:00 46086       164.0   4.9  5.9   NaN    NaN   NaN    NaN
# 2023-01-01 00:30:00 46086       164.0   5.3  6.6   NaN    NaN   NaN    NaN
# 2023-01-01 00:40:00 46086       162.0   5.2  6.6  1.88  13.79  9.55  257.0
#
#                                   PRES  ATMP  WTMP  DEWP  VIS  TIDE  PTDY
# timestamp           station_id
# 2023-01-01 00:00:00 46086       1014.3  14.8  15.9  13.7  NaN   NaN   NaN
# 2023-01-01 00:10:00 46086       1014.2  14.9  15.9  13.8  NaN   NaN   NaN
# 2023-01-01 00:20:00 46086       1014.1  14.9  15.9  13.8  NaN   NaN   NaN
# 2023-01-01 00:30:00 46086       1014.1  14.9  15.9  13.9  NaN   NaN   NaN
# 2023-01-01 00:40:00 46086       1014.0  14.9  15.9  14.0  NaN   NaN   NaN

# %% [markdown]
# ## Transform
#
# Curate raw data. Standardize and filter out values.

# %%
# Clean and add features
data = clean_ndbc_data(raw_data, BUOY_ID)

# %%
data.head()
# Out:
#                                 wind_direction  wind_speed  wind_gust  \
# timestamp           station_id
# 2023-01-01 00:10:00 46086                172.0         4.7        5.9
# 2023-01-01 00:40:00 46086                162.0         5.2        6.6
# 2023-01-01 01:10:00 46086                154.0         5.8        7.2
# 2023-01-01 01:40:00 46086                162.0         6.2        7.3
# 2023-01-01 02:10:00 46086                176.0         7.0        8.2
#
#                                 wave_height  dominant_wave_period  \
# timestamp           station_id
# 2023-01-01 00:10:00 46086              1.63                 11.43
# 2023-01-01 00:40:00 46086              1.88                 13.79
# 2023-01-01 01:10:00 46086              1.68                 12.12
# 2023-01-01 01:40:00 46086              1.80                 12.12
# 2023-01-01 02:10:00 46086              1.76                 11.43
#
#                                 average_wave_period  mean_wave_direction  \
# timestamp           station_id
# 2023-01-01 00:10:00 46086                      9.33                283.0
# 2023-01-01 00:40:00 46086                      9.55                257.0
# 2023-01-01 01:10:00 46086                      8.98                271.0
# 2023-01-01 01:40:00 46086                      8.99                270.0
# 2023-01-01 02:10:00 46086                      8.94                263.0
#
#                                 pressure  air_temperature  water_temperature  \
# timestamp           station_id
# 2023-01-01 00:10:00 46086         1014.2             14.9               15.9
# 2023-01-01 00:40:00 46086         1014.0             14.9               15.9
# 2023-01-01 01:10:00 46086         1013.5             14.9               15.9
# 2023-01-01 01:40:00 46086         1013.1             15.0               15.9
# 2023-01-01 02:10:00 46086         1012.7             15.0               15.9
#
#                                 dewpoint_temperature  wind_speed_ms  \
# timestamp           station_id
# 2023-01-01 00:10:00 46086                       13.8       2.417887
# 2023-01-01 00:40:00 46086                       14.0       2.675109
# 2023-01-01 01:10:00 46086                       14.1       2.983775
# 2023-01-01 01:40:00 46086                       14.3       3.189553
# 2023-01-01 02:10:00 46086                       14.3       3.601108
#
#                                 wave_energy   buoy
# timestamp           station_id
# 2023-01-01 00:10:00 46086         30.368367  46086
# 2023-01-01 00:40:00 46086         48.739376  46086
# 2023-01-01 01:10:00 46086         34.207488  46086
# 2023-01-01 01:40:00 46086         39.268800  46086
# 2023-01-01 02:10:00 46086         35.405568  46086

# %%
len(data)
# Out:
# 35681

# %%
data.isna().sum()
# Out:
# wind_direction          0
# wind_speed              0
# wind_gust               0
# wave_height             0
# dominant_wave_period    0
# average_wave_period     0
# mean_wave_direction     0
# pressure                0
# air_temperature         0
# water_temperature       0
# dewpoint_temperature    0
# wind_speed_ms           0
# wave_energy             0
# buoy                    0
# dtype: int64

# %%
data.describe()
# Out:
#        wind_direction    wind_speed     wind_gust   wave_height  \
# count    35681.000000  35681.000000  35681.000000  35681.000000
# mean       260.597797      4.342291      5.763911      1.531325
# std         80.488737      2.333692      2.700273      0.628473
# min          1.000000      0.000000      0.000000      0.400000
# 25%        253.000000      2.600000      3.900000      1.120000
# 50%        289.000000      4.000000      5.400000      1.360000
# 75%        304.000000      5.700000      7.200000      1.750000
# max        360.000000     15.700000     20.500000      6.350000
#
#        dominant_wave_period  average_wave_period  mean_wave_direction  \
# count          35681.000000         35681.000000         35681.000000
# mean              12.604738             7.165101           252.685295
# std                3.245569             1.602884            44.550444
# min                3.000000             3.400000             4.000000
# 25%               10.000000             6.010000           212.000000
# 50%               12.900000             6.870000           273.000000
# 75%               14.810000             8.000000           287.000000
# max               23.530000            15.500000           357.000000
#
#            pressure  air_temperature  water_temperature  dewpoint_temperature  \
# count  35681.000000     35681.000000       35681.000000          35681.000000
# mean    1014.769508        16.233561          17.527984             13.063692
# std        3.701237         2.187636           2.219967              3.104017
# min      997.100000         9.700000          13.200000             -3.900000
# 25%     1012.200000        14.600000          15.700000             11.200000
# 50%     1014.500000        16.000000          17.300000             13.100000
# 75%     1017.100000        17.900000          19.500000             15.400000
# max     1028.300000        22.500000          23.000000             21.200000
#
#        wind_speed_ms   wave_energy
# count   35681.000000  35681.000000
# mean        2.233866     34.518358
# std         1.200554     38.681358
# min         0.000000      1.080000
# 25%         1.337554     14.915264
# 50%         2.057776     23.140625
# 75%         2.932331     38.400000
# max         8.076771    667.633920

# %%
plot_ndbc_histograms(data)

# %% [markdown]
# ## Load
#
# Serialize and upload directly to S3.

# %%
# Upload to S3
CURATED_PREFIX = "curated/ndbc"
s3_path = upload_df_to_s3(data, bucket, CURATED_PREFIX, BUOY_ID, s3_client=s3_client)
# Out:
# [INFO] Uploaded to s3://sagemaker-us-east-1-318401170150/curated/ndbc/buoy=46086/stdmet.parquet

# %%
# %store CURATED_PREFIX
# %store bucket
# Out:
# Stored 'CURATED_PREFIX' (str)
# Stored 'bucket' (str)

# %%
from IPython.core.display import display, HTML
import boto3

# Get region from your boto3 client/session
region = boto3.Session().region_name

# Build the S3 console URL for your bucket
s3_console_url = (
    f"https://s3.console.aws.amazon.com/s3/buckets/{bucket}/"
    f"?region={region}&tab=overview"
)

display(
    HTML(
        f'<b>Review <a target="_blank" href="{s3_console_url}">S3 Bucket</a></b>'
    )
)
# Out:
# /tmp/ipykernel_3244/914977500.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
# <b>Review <a target="_blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-318401170150/?region=us-east-1&tab=overview">S3 Bucket</a></b>

# %% [markdown]
# ## Cleanup
# ### Store Variables

# %%
# %store s3_path
# Out:
# Stored 's3_path' (str)

# %% [markdown]
# ## Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
